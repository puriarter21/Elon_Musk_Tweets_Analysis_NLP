# %% [markdown]
# # Sentiment Analysis of Elon Musk's Tweets
# This project focuses on performing sentiment analysis of tweets posted by Elon Musk, one of the most influential entrepreneurs and visionaries of our time. Through tweet processing and analysis, we aim to gain valuable insights into the sentiments expressed in his tweets and their impact on public perception.
#
#
# ## Notebook Contents.
#
# ### 1. Data preview
#
# ### 2. Data Preparation:
#     -This section includes code and resources for cleaning and preprocessing the tweets, including the removal of mentions, URLs, and unwanted symbols.
#
#     -While also including a data pre processing section focused on feature engineering.
#
# ### 3. Exploratory Analysis:
#
# ### Sentiment Analysis:
#     -Here, you will find the code for conducting sentiment analysis of the tweets using natural language processing techniques. This will enable us to classify the tweets as positive, negative, or neutral.
#
# ### Results Visualization:
# In this section, interactive visualizations of the sentiment analysis results are provided. This will help us understand trends and changes in sentiment over time.
#
# ### Research Questions:
#
# ### Conclusions:

# %% [markdown]
# ## 1. Data preview
#
#     -Import the necessary python libriaries
#     -General oversee of what the data looks like (# Columns, Data types, NaN check)

# %%
# Libraries
import pandas as pd  # Library for data manipulation and analysis
import matplotlib.pyplot as plt  # Library for creating visualizations
import seaborn as sns  # Library for statistical data visualization

import nltk  # Natural Language Toolkit library
from nltk.stem import WordNetLemmatizer  # Lemmatization library
from nltk.corpus import wordnet  # Lexical database for English language
from nltk import pos_tag, word_tokenize  # Functions for part-of-speech tagging and tokenization

from nltk.stem.snowball import SnowballStemmer  # Snowball Stemming Algorithm library
from nltk.tokenize import word_tokenize  # Function for tokenization
from nltk.corpus import stopwords  # Stopwords corpus
from nltk import ngrams  # Functions for creating n-grams

nltk.download('averaged_perceptron_tagger')  # Downloading the pre-trained model for part-of-speech tagging
nltk.download('punkt')  # Downloading the tokenizer models
nltk.download('wordnet')  # Downloading WordNet lexical database
nltk.download('stopwords')  # Downloading the stopwords corpus

import re  # Regular expression operations library
import random  # Library for generating random numbers

from collections import Counter  # Library for counting elements in a list
from wordcloud import WordCloud  # Library for creating word clouds

import emoji  # Library for working with emojis
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/puriarte/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /home/puriarte/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/puriarte/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/puriarte/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
bd_tw = pd.read_csv('Data/elonmusk.csv')

# %%
bd_tw.head()
# Out:
#                     Datetime             Tweet Id  \
# 0  2023-05-29 22:22:12+00:00  1663309794659168256
# 1  2023-05-29 22:21:43+00:00  1663309674194649089
# 2  2023-05-29 21:33:29+00:00  1663297534062673920
# 3  2023-05-29 20:04:12+00:00  1663275065696239653
# 4  2023-05-29 19:44:54+00:00  1663270209598246912
#
#                                                 Text  Username
# 0              @mattyglesias Now answer the question  elonmusk
# 1               @mattyglesias Insufferable numbskull  elonmusk
# 2                                   @EndWokeness Yes  elonmusk
# 3                                      @SethDillon 🤣  elonmusk
# 4  @TeslaOwnersEBay @stevenmarkryan @WholeMarsBlo...  elonmusk

# %%
bd_tw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23501 entries, 0 to 23500
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datetime  23501 non-null  object
#  1   Tweet Id  23501 non-null  int64
#  2   Text      23501 non-null  object
#  3   Username  23501 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 734.5+ KB

# %%
# Checking for NaN just in case.
nan_check = bd_tw.isna().any()
nan_check
# Out:
# Datetime    False
# Tweet Id    False
# Text        False
# Username    False
# dtype: bool

# %% [markdown]
# #### Notes:
#     -No NaN found in any column
#     -Interest Columns are object dtypes

# %% [markdown]
# # 2. Data Preparation:
#
# We'll do some basic cleaning and a little feature engineering as well.
#
#     -1. Standarize column names turn to lower case.
#     -2. We'll split the "datetime" column so we can be better at splitting periods of time and hours of the day later in the analysis
#     -3. Columns "tweet_id" & "username" not really useful so we can drop them

# %%
##1 Change column names to lower case and remove spaces
bd_tw.columns = [col.lower().replace(' ', '_') for col in bd_tw.columns]

# %%
##2 Convert the "datetime" column to datetime format
bd_tw['datetime'] = pd.to_datetime(bd_tw['datetime'])

## Create new 'date' column
bd_tw['date'] = bd_tw['datetime'].dt.date

## Create new 'hour' column
bd_tw['hour'] = bd_tw['datetime'].dt.hour

# %%
# Convert 'date' column to datetime object
bd_tw['date'] = pd.to_datetime(bd_tw['date'])

# %%
##3 Drop unuseful columns
bd_tw.drop(columns=['tweet_id', 'username'], inplace=True)
bd_tw.drop(columns=['datetime'], inplace=True)

#Making every letter to be lower case
bd_tw['text'] = bd_tw['text'].str.lower()

# %%
# Reorder the DataFrame
bd_tw = bd_tw[['date', 'hour', 'text']]

# %% [markdown]
# ### 2.1 Text Data Preprocessing
#
# #### For our NLP work we need to do some preprocessing of out data and feature generation out of the text column data.
#
#     -1 Create a new text column free of usernames, emojis
#     -2 Remove stop words.
#     -3 Tokenize the text
#     -4 Remove URLs
#     -5 Remove non-alphabetic characters
#     -6 Lemmatize the text
#
#
# #### Notes:
#
#     -Final working column will be "lemmatized_text"
#     -I kept the original "text" column and the "proprocessed text"(which keeps non-alphabetic characters just in case we can use those later)

# %%
##(Column:lemmatized_text )

#1 Create a new text column free of usernames, emojis
#2 Remove stop words 
#3 Tokenize the text

# Define the set of stop words
stop_words = set(stopwords.words('english'))

def preprocess_text_sw(text):
    # Remove mentions
    text = re.sub(r'@\w+', '', text)

    # Remove emojis
    text = emoji.demojize(text)
    text = re.sub(r':[a-zA-Z_&]+:', '', text)

    # Tokenize the words
    word_tokens = word_tokenize(text)

    # Filter out the stop words
    filtered_text = [word for word in word_tokens if not word in stop_words]

    return " ".join(filtered_text)

# Apply the preprocessing to the text column
bd_tw['preprocessed_text'] = bd_tw['text'].apply(preprocess_text_sw)

# %%
#4 Remove URLs
def remove_urls(text):
    url_pattern = re.compile(r'(https?|www)[\s:/.A-Za-z0-9]*|//t\.co/\S*')
    return url_pattern.sub(r'', text)

# Apply the URL removal to the preprocessed_text column
bd_tw['preprocessed_text'] = bd_tw['preprocessed_text'].apply(remove_urls)

# %%
#5 Remove non-alphabetic characters
def preprocess_lemmatize_text(text):
    # Replace underscores with spaces
    text = re.sub(r'_', ' ', text)
    
    # Remove all non-alphabetic characters
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    
    return text

# Apply the preprocessing to the preprocessed_text column and store the result in a new column
bd_tw['lemmatized_text'] = bd_tw['preprocessed_text'].apply(preprocess_lemmatize_text)

# %%
#6 Lemmatize the text (Column:lemmatized_text )

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# This function converts nltk pos-tags to WordNet pos-tags
def get_wordnet_pos(nltk_pos):
    if nltk_pos.startswith('J'):
        return wordnet.ADJ
    elif nltk_pos.startswith('V'):
        return wordnet.VERB
    elif nltk_pos.startswith('N'):
        return wordnet.NOUN
    elif nltk_pos.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def lemmatize_text(text):
    nltk_pos_tagged = pos_tag(word_tokenize(text))
    wordnet_pos_tagged = list(map(lambda x: (x[0], get_wordnet_pos(x[1])), nltk_pos_tagged))
    lemmatized_text = list(map(lambda x: lemmatizer.lemmatize(x[0], pos=x[1]), wordnet_pos_tagged))
    return " ".join(lemmatized_text)

# Apply the lemmatization to the lemmatized_text column
bd_tw['lemmatized_text'] = bd_tw['lemmatized_text'].apply(lemmatize_text)

# %%
#FIRST WORD CLOUD (Column:lemmatized_text )

#Concatenate all the preprocessed text together
all_text = ' '.join(bd_tw['lemmatized_text'])

# Generate the word cloud
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = None, 
                min_font_size = 10).generate(all_text)

# Plot the word cloud
plt.figure(figsize = (4, 4), facecolor = None) 
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# ### Feature engineering
#
#
# #### We'll also test some new columns.
#
#     -Creat a new column with the @users tagged in the twits
#     -Well use named entity recognition to see what other information we can get
#
#     -1. Add a new column for text length
#     -2. Extract Emojis from the raw text column using a regular expression to match any emoji
#     -3. Extract interactions with other users, creating a new column called "usernames".
#
#
#    #### Notas:
#
#        -Necesito hacer que los emojis solo aparezcan una vez en la columna emoji

# %%
bd_tw.head(60)
# Out:
#          date                                               text  text_length  \
# 0  2023-05-29              @mattyglesias now answer the question           37
# 1  2023-05-29               @mattyglesias insufferable numbskull           36
# 2  2023-05-29                                   @endwokeness yes           16
# 3  2023-05-29                                      @sethdillon 🤣           13
# 4  2023-05-29  @teslaownersebay @stevenmarkryan @wholemarsblo...          107
# 5  2023-05-29      also, you can now change video playback speed           45
# 6  2023-05-29                  @krassenstein this is pretty cool           33
# 7  2023-05-29  @stevenmarkryan @wholemarsblog heard diablo iv...           94
# 8  2023-05-29    @joeys_lady @stevenmarkryan @wholemarsblog true           47
# 9  2023-05-29                         @drknowitall16 coming soon           26
# 10 2023-05-29                          @eldsjal what is a woman?           25
# 11 2023-05-29  scrolling through tweets while watching mini v...           72
# 12 2023-05-29  @streamonmax lot of flack for the branding cha...           84
# 13 2023-05-29                              @trhlofficial exactly           21
# 14 2023-05-29               🇺🇸 for those who died for freedom 🇺🇸           36
# 15 2023-05-29                                        @aocpress 🔥           11
# 16 2023-05-29  @davidsacks commercial real estate is melting ...           74
# 17 2023-05-29  @cmdr_hadfield the china space program is far ...           84
# 18 2023-05-29                               @cremieuxrecueil wow           20
# 19 2023-05-29  what will ai be like in 2040? https://t.co/sdh...           53
# 20 2023-05-29                                    @libertycappy 🤨           15
# 21 2023-05-29                               @monitoringbias true           20
# 22 2023-05-29                                  @zerohedge zero …           17
# 23 2023-05-29  @trhlofficial @mattyglesias yeah, answer the q...           54
# 24 2023-05-29                                   @teslasynopsis 🤣           16
# 25 2023-05-29  @teslatino sorry, this is one of the last neur...          120
# 26 2023-05-29            @growing_daniel https://t.co/5liklahx7f           39
# 27 2023-05-29                          @libertycappy sounds true           25
# 28 2023-05-29  @nro @ariblaff did they really fire people for...           66
# 29 2023-05-29  incompetence, in the limit, is indistinguishab...           62
# 30 2023-05-29                    @forbes https://t.co/t2wgpnec2q           31
# 31 2023-05-29  @forbes actually, the meme is showing the absu...          130
# 32 2023-05-29                                        @jason why?           11
# 33 2023-05-29  @peterdiamandis if shooting oneself in the foo...          108
# 34 2023-05-29  @mysteriouskat “use of chatgpt is rampant amon...           80
# 35 2023-05-29  @scobleizer i realize the implicit irony in sa...           96
# 36 2023-05-29                                          @0xgaut 🤔            9
# 37 2023-05-29          @adamdangelo needs a better name, but yes           41
# 38 2023-05-29  transparency builds trust … https://t.co/awahx...           51
# 39 2023-05-28  @sriramk @aarthir whole podcast uploaded to th...           58
# 40 2023-05-28  @mattyglesias you’re such a numbskull. please ...          109
# 41 2023-05-28                                 @logic_commander ?           18
# 42 2023-05-28                             @andst7 major problem!           22
# 43 2023-05-28      @zerohedge for obvious &amp; sensible reasons           45
# 44 2023-05-28                      @mysteriouskat @hubermanlab 💯           29
# 45 2023-05-28                  @tocharus https://t.co/yeyylv2fbz           33
# 46 2023-05-28                              @aakashg0 interesting           21
# 47 2023-05-28  @historyinmemes he was a bamf for sure, but “b...           87
# 48 2023-05-28                       @cwhowell123 it’s epic at bs           28
# 49 2023-05-28    @wallstreetsilv let’s see how the vote pans out           47
# 50 2023-05-28                            @slashdot inevitable 🤣🤣           23
# 51 2023-05-28                      @lathyrusb @trhlofficial true           29
# 52 2023-05-28                             @trhlofficial accurate           22
# 53 2023-05-28                              @greg_price11 really?           21
# 54 2023-05-28                      yikes https://t.co/qvuqx123gt           29
# 55 2023-05-28                                          @yishan 👀            9
# 56 2023-05-28                @thackerpd @rondesantis interesting           35
# 57 2023-05-28                                    @backthebunny 🤣           15
# 58 2023-05-28                                    @gmoneynft nice           15
# 59 2023-05-28                                       @micsolana 🤣           12
#
#                                     preprocessed_text  \
# 0                                     answer question
# 1                              insufferable numbskull
# 2                                                 yes
# 3
# 4              later year . definitely needs happen !
# 5                  also , change video playback speed
# 6                                         pretty cool
# 7   heard diablo iv might good . remake system sho...
# 8                                                true
# 9                                         coming soon
# 10                                            woman ?
# 11  scrolling tweets watching mini video ( pic pic...
# 12        lot flack branding change , think work well
# 13                                            exactly
# 14                                       died freedom
# 15
# 16  commercial real estate melting fast . home val...
# 17    china space program far advanced people realize
# 18                                                wow
# 19                                    ai like 2040 ?
# 20
# 21                                               true
# 22                                             zero …
# 23                           yeah , answer question !
# 24
# 25  sorry , one last neural nets updated surround ...
# 26
# 27                                        sounds true
# 28                really fire people calling police ?
# 29  incompetence , limit , indistinguishable sabotage
# 30
# 31  actually , meme showing absurdity statement no...
# 32                                                  ?
# 33   shooting oneself foot disrupting , would say lot
# 34  “ use chatgpt rampant among students today ” –...
# 35  realize implicit irony saying , highest ’ paid...
# 36
# 37                            needs better name , yes
# 38                       transparency builds trust …
# 39                  whole podcast uploaded platform !
# 40  ’ numbskull . please point actual choice rever...
# 41                                                  ?
# 42                                    major problem !
# 43                   obvious & amp ; sensible reasons
# 44
# 45
# 46                                        interesting
# 47        bamf sure , “ bull moose party ” great name
# 48                                          ’ epic bs
# 49                                let ’ see vote pans
# 50                                         inevitable
# 51                                               true
# 52                                           accurate
# 53                                           really ?
# 54                                             yikes
# 55
# 56                                        interesting
# 57
# 58                                               nice
# 59
#
#                                       lemmatized_text  \
# 0                                     answer question
# 1                              insufferable numbskull
# 2                                                 yes
# 3
# 4                   later year definitely need happen
# 5                    also change video playback speed
# 6                                         pretty cool
# 7   heard diablo iv might good remake system shock...
# 8                                                true
# 9                                           come soon
# 10                                              woman
# 11        scroll tweet watch mini video pic pic great
# 12             lot flack brand change think work well
# 13                                            exactly
# 14                                        die freedom
# 15
# 16   commercial real estate melt fast home value next
# 17    china space program far advanced people realize
# 18                                                wow
# 19                                            ai like
# 20
# 21                                               true
# 22                                               zero
# 23                               yeah answer question
# 24
# 25  sorry one last neural net update surround vide...
# 26
# 27                                         sound true
# 28                     really fire people call police
# 29      incompetence limit indistinguishable sabotage
# 30
# 31  actually meme show absurdity statement note tr...
# 32
# 33           shoot oneself foot disrupt would say lot
# 34  use chatgpt rampant among student today studen...
# 35           realize implicit irony say high paid far
# 36
# 37                                 need well name yes
# 38                           transparency build trust
# 39                      whole podcast upload platform
# 40       numbskull please point actual choice reverse
# 41
# 42                                      major problem
# 43                        obvious amp sensible reason
# 44
# 45
# 46                                           interest
# 47              bamf sure bull moose party great name
# 48                                             epic b
# 49                                   let see vote pan
# 50                                         inevitable
# 51                                               true
# 52                                           accurate
# 53                                             really
# 54                                              yikes
# 55
# 56                                           interest
# 57
# 58                                               nice
# 59
#
#                                             usernames emoji  hour  month  year
# 0                                       @mattyglesias          22      5  2023
# 1                                       @mattyglesias          22      5  2023
# 2                                        @endwokeness          21      5  2023
# 3                                         @sethdillon     🤣    20      5  2023
# 4   @teslaownersebay,@stevenmarkryan,@wholemarsblo...          19      5  2023
# 5                                                 NaN          19      5  2023
# 6                                       @krassenstein          19      5  2023
# 7                      @stevenmarkryan,@wholemarsblog          19      5  2023
# 8          @joeys_lady,@stevenmarkryan,@wholemarsblog          18      5  2023
# 9                                      @drknowitall16          18      5  2023
# 10                                           @eldsjal          18      5  2023
# 11                                                NaN          18      5  2023
# 12                                       @streamonmax          18      5  2023
# 13                                      @trhlofficial          18      5  2023
# 14                                                NaN    🇺🇸    18      5  2023
# 15                                          @aocpress     🔥    17      5  2023
# 16                                        @davidsacks          17      5  2023
# 17                                     @cmdr_hadfield          17      5  2023
# 18                                   @cremieuxrecueil          16      5  2023
# 19                                                NaN          16      5  2023
# 20                                      @libertycappy     🤨    15      5  2023
# 21                                    @monitoringbias          15      5  2023
# 22                                         @zerohedge          10      5  2023
# 23                        @trhlofficial,@mattyglesias           7      5  2023
# 24                                     @teslasynopsis     🤣     7      5  2023
# 25                                         @teslatino           7      5  2023
# 26                                    @growing_daniel           6      5  2023
# 27                                      @libertycappy           5      5  2023
# 28                                     @nro,@ariblaff           5      5  2023
# 29                                                NaN           2      5  2023
# 30                                            @forbes           2      5  2023
# 31                                            @forbes           2      5  2023
# 32                                             @jason           2      5  2023
# 33                                    @peterdiamandis           2      5  2023
# 34                                     @mysteriouskat           1      5  2023
# 35                                        @scobleizer           1      5  2023
# 36                                            @0xgaut     🤔     1      5  2023
# 37                                       @adamdangelo           0      5  2023
# 38                                                NaN           0      5  2023
# 39                                  @sriramk,@aarthir          22      5  2023
# 40                                      @mattyglesias          19      5  2023
# 41                                   @logic_commander          19      5  2023
# 42                                            @andst7          19      5  2023
# 43                                         @zerohedge          10      5  2023
# 44                        @mysteriouskat,@hubermanlab     💯     9      5  2023
# 45                                          @tocharus           9      5  2023
# 46                                          @aakashg0           9      5  2023
# 47                                    @historyinmemes           9      5  2023
# 48                                       @cwhowell123           8      5  2023
# 49                                    @wallstreetsilv           8      5  2023
# 50                                          @slashdot    🤣🤣     8      5  2023
# 51                           @lathyrusb,@trhlofficial           8      5  2023
# 52                                      @trhlofficial           8      5  2023
# 53                                      @greg_price11           3      5  2023
# 54                                                NaN           3      5  2023
# 55                                            @yishan     👀     3      5  2023
# 56                            @thackerpd,@rondesantis           3      5  2023
# 57                                      @backthebunny     🤣     3      5  2023
# 58                                         @gmoneynft           3      5  2023
# 59                                         @micsolana     🤣     3      5  2023

# %%
# 1. Add a new column for text length
bd_tw.loc[:, 'text_length'] = bd_tw['text'].str.len()

# %%
#2. Extract Emojis from the raw text column using a regular expression to match any emoji
emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U0001F700-\U0001F77F"  # alchemical symbols
                           u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                           u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                           u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                           u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                           u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                           u"\U00002702-\U000027B0"  # Dingbats
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)

# Define a function that extracts unique emojis from a string
def extract_unique_emojis(text):
    emojis = re.findall(emoji_pattern, text)
    unique_emojis = list(set(emojis))
    return ', '.join(unique_emojis)

# Apply the function to the 'text' column and assign the result to the 'emoji' column
bd_tw['emoji'] = bd_tw['text'].apply(extract_unique_emojis)

# %%
#3. Creating a new column called "usernames"
bd_tw['usernames'] = bd_tw['text'].str.extractall(r'(@\w+)')[0].groupby(level=0).apply(','.join)

# %%
#re arrange columns every time is needed
arranged_columns = ['date', 'text', 'text_length', 'preprocessed_text', 'lemmatized_text', 'usernames', 'emoji']
bd_tw = bd_tw[arranged_columns + [col for col in bd_tw.columns if col not in desired_columns]]

# %% [markdown]
# ### Findings
#
# #### The data base:
#
#     -Records twits from 2010-06-04 to 2023-05-29
#     -Has emojis (which can help the sentiment analysis)
#     -"@" refers to people (which we can try to use to valuate sentiments with other people)

# %% [markdown]
# ## 3. Exploratory Analysis:

# %%
# Extract month from date column
bd_tw['month'] = bd_tw['date'].dt.month
# Calculate tweet counts for each month
monthly_tweets = bd_tw['month'].value_counts().sort_index()

# Generate the plot
plt.figure(figsize=(10, 6))
sns.barplot(x=monthly_tweets.index, y=monthly_tweets.values, color='b')
plt.xlabel('Month')
plt.ylabel('Number of Tweets')
plt.title('Average Number of Tweets per Month')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
# Get a Series with usernames as index and their counts as values
username_counts = bd_tw['usernames'].value_counts()

# Convert the Series to a DataFrame for better visualisation
username_counts_df = username_counts.reset_index()

# Rename the columns for clarity
username_counts_df.columns = ['usernames', 'count']

# Display the DataFrame
print(username_counts_df)
# Out:
#                                          usernames  count
# 0                                   @wholemarsblog    331
# 1                                        @billym2k    276
# 2                                   @teslaownerssv    183
# 3                                  @erdayastronaut    126
# 4                                        @ppathole    122
# ...                                            ...    ...
# 9967  @doge_southern,@truth_tesla,@consumerreports      1
# 9968                                    @sluigi123      1
# 9969                     @cmuratori,@id_aa_carmack      1
# 9970                       @tesla4k,@matanmazursky      1
# 9971                                    @jonlovett      1
#
# [9972 rows x 2 columns]

# %%
print(username_counts_df.head(50))
# Out:
#            usernames  count
# 0     @wholemarsblog    331
# 1          @billym2k    276
# 2     @teslaownerssv    183
# 3    @erdayastronaut    126
# 4          @ppathole    122
# 5     @rainmaker1973    115
# 6           @cb_doge    114
# 7     @cleantechnica    108
# 8           @flcnhvy    104
# 9           @evafoxu     99
# 10        @teslarati     97
# 11           @spacex     84
# 12   @engineers_feed     83
# 13   @wallstreetsilv     80
# 14       @trungtphan     79
# 15       @nichegamer     77
# 16       @lexfridman     74
# 17    @thebabylonbee     74
# 18      @sciguyspace     72
# 19       @waitbutwhy     67
# 20    @sawyermerritt     67
# 21        @stillgray     65
# 22         @slashdot     61
# 23       @davidsacks     61
# 24   @muskuniversity     60
# 25        @micsolana     56
# 26           @pmarca     56
# 27    @id_aa_carmack     55
# 28  @nasaspaceflight     54
# 29  @dogeofficialceo     51
# 30    @westcoastbill     47
# 31    @tesmanian_com     46
# 32  @kanekoathegreat     44
# 33            @jason     43
# 34              @alx     42
# 35           @andst7     41
# 36  @worldandscience     41
# 37    @kristennetten     41
# 38            @tesla     38
# 39      @ashleevance     37
# 40   @stevenmarkryan     35
# 41  @therabbithole84     35
# 42    @teslaconomics     34
# 43            @mkbhd     34
# 44       @archillect     33
# 45  @fredericlambert     33
# 46     @model3owners     33
# 47        @zubymusic     33
# 48        @farzyness     33
# 49            @paulg     32

# %%
bd_tw['year'] = bd_tw['date'].dt.year

# %%
# Group by year and username, count the number of occurrences of each pair
username_counts_year = bd_tw.groupby(['year', 'usernames']).size()

# Iterate over each year and print the top usernames
for year in bd_tw['year'].unique():
    top_usernames = username_counts_year[year].nlargest(10)
    print(f"Top usernames for year {year}:")
    print(top_usernames)
    print()
# Out:
# Top usernames for year 2023:
# usernames
# @billym2k           97
# @cb_doge            96
# @wallstreetsilv     66
# @wholemarsblog      59
# @thebabylonbee      47
# @trungtphan         43
# @kanekoathegreat    42
# @alx                41
# @dogeofficialceo    41
# @teslaownerssv      41
# dtype: int64
#
# Top usernames for year 2022:
# usernames
# @wholemarsblog    152
# @billym2k         138
# @teslaownerssv     59
# @rainmaker1973     51
# @evafoxu           43
# @ppathole          41
# @pmarca            39
# @sawyermerritt     37
# @stillgray         36
# @lexfridman        31
# dtype: int64
#
# Top usernames for year 2021:
# usernames
# @wholemarsblog      96
# @teslaownerssv      45
# @billym2k           41
# @ppathole           37
# @erdayastronaut     26
# @rainmaker1973      26
# @lexfridman         24
# @thesheetztweetz    23
# @engineers_feed     22
# @cleantechnica      21
# dtype: int64
#
# Top usernames for year 2020:
# usernames
# @flcnhvy           58
# @teslarati         48
# @cleantechnica     45
# @erdayastronaut    44
# @ppathole          41
# @thirdrowtesla     29
# @engineers_feed    27
# @sciguyspace       27
# @wholemarsblog     24
# @nichegamer        23
# dtype: int64
#
# Top usernames for year 2019:
# usernames
# @erdayastronaut     34
# @teslarati          33
# @cleantechnica      30
# @flcnhvy            28
# @spacex             20
# @tesla              19
# @nichegamer         18
# @teslaownerssv      16
# @tesla_truth        13
# @worldandscience    13
# dtype: int64
#
# Top usernames for year 2018:
# usernames
# @fredericlambert                14
# @electrekco,@fredericlambert    12
# @dmc_ryan                       11
# @worldandscience                11
# @lanceulanoff                   10
# @model3owners                   10
# @antvenom                        8
# @boringcompany                   8
# @cleantechnica                   8
# @nichegamer                      8
# dtype: int64
#
# Top usernames for year 2017:
# usernames
# @fredericlambert    7
# @businessinsider    6
# @newscientist       6
# @redletterdave      6
# @verge              6
# @danahull           5
# @rickandmorty       5
# @jovanik21          4
# @mcannonbrookes     4
# @smilesimplify      4
# dtype: int64
#
# Top usernames for year 2016:
# usernames
# @vicentes                     8
# @mactechgenius                5
# @elonmusk                     4
# @id_aa_carmack                4
# @lukealization                4
# @spacex                       4
# @swiftonsecurity              4
# @alansmurray                  3
# @danahull                     3
# @disinformatico,@eddy_jahn    3
# dtype: int64
#
# Top usernames for year 2015:
# usernames
# @id_aa_carmack      8
# @elonmusk           5
# @bonnienorman       3
# @consumerreports    2
# @drew               2
# @kevinmitnick       2
# @scottlucasnv       2
# @aaronpaul_8        1
# @abrax4s            1
# @achailleux         1
# dtype: int64
#
# Top usernames for year 2014:
# usernames
# @id_aa_carmack                    2
# @nasa,@spacex                     2
# @nasaspaceflight                  2
# @oatmeal                          2
# @olejandersen                     2
# @quantumg                         2
# @senjohnmccain                    2
# @westcoastbill                    2
# @akabrahamson,@itsdanielsuarez    1
# @arstechnica,@joemullin           1
# dtype: int64
#
# Top usernames for year 2013:
# usernames
# @teslamotors       4
# @arthurblake       3
# @rebel_sal         3
# @spacex            3
# @tierrauniversu    3
# @batasrki          2
# @bjartereve        2
# @chrysler          2
# @danabrunetti      2
# @justinchace       2
# dtype: int64
#
# Top usernames for year 2012:
# usernames
# @nasa             8
# @fareedzakaria    3
# @danretz          2
# @dansitu          2
# @solarcity        2
# @spacex           2
# @adeoressi        1
# @astro_yyz        1
# @bentobewild      1
# @bm_              1
# dtype: int64
#
# Top usernames for year 2011:
# usernames
# @kanyewest         1
# @mayemusk          1
# @om                1
# @richardbranson    1
# @theonion          1
# dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 6
#       4 # Iterate over each year and print the top usernames
#       5 for year in bd_tw['year'].unique():
# ----> 6     top_usernames = username_counts_year[year].nlargest(10)
#       7     print(f"Top usernames for year {year}:")
#       8     print(top_usernames)
#
# File ~/TC5031/tc5031/lib/python3.10/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/TC5031/tc5031/lib/python3.10/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/TC5031/tc5031/lib/python3.10/site-packages/pandas/core/indexes/multi.py:2869, in MultiIndex.get_loc(self, key, method)
#    2866     return mask
#    2868 if not isinstance(key, tuple):
# -> 2869     loc = self._get_level_indexer(key, level=0)
#    2870     return _maybe_to_slice(loc)
#    2872 keylen = len(key)
#
# File ~/TC5031/tc5031/lib/python3.10/site-packages/pandas/core/indexes/multi.py:3249, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3245     end = level_codes.searchsorted(idx, side="right")
#    3247 if start == end:
#    3248     # The label is present in self.levels[level] but unused:
# -> 3249     raise KeyError(key)
#    3250 return slice(start, end)
#
# KeyError: 2010

# %%
# Group by year and count the number of tweets per year
tweet_counts_per_year = bd_tw['year'].value_counts().sort_index()

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(tweet_counts_per_year.index, tweet_counts_per_year.values)
plt.xlabel('Year')
plt.ylabel('Tweet Count')
plt.title('Tweet Counts per Year')
plt.xticks(rotation=45)
plt.show()

# %%
unique_emojis = bd_tw['emoji'].unique()
print(unique_emojis)

# %%
# Create a new column 'emoji' and initialize it as empty
bd_tw['emoji'] = ''

# Iterate over each row in the DataFrame
for index, row in bd_tw.iterrows():
    text = row['text']
    emojis = re.findall(emoji_pattern, text)
    unique_emojis = set(emojis)
    bd_tw.at[index, 'emoji'] = ' '.join(unique_emojis)

# Count the occurrences of each emoji
emoji_counts = bd_tw['emoji'].str.split(expand=True).stack().value_counts()

# Print the most appeared emojis
print("Top appeared emojis:")
print(emoji_counts.head())
